# %% [markdown]
# <a href="https://colab.research.google.com/github/cherry880706/IDS/blob/master/week3%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
movie_title = "Avengers: Endgame"
movie_length = 181
movie_rating = 8.4

print(movie_title)
print(movie_length)
print(movie_rating)

print(type(movie_title))
print(type(movie_length))
print(type(movie_rating))
# Out:
# Avengers: Endgame
# 181
# 8.4
# <class 'str'>
# <class 'int'>
# <class 'float'>
